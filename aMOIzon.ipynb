# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome('./chromedriver.exe')
# Out:
# C:\Users\LeoDOYEN\AppData\Local\Temp\ipykernel_10920\913636808.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver.exe')

# %%
driver.get('https://www.amazon.fr')

# %%
driver.current_url
# Out:
# 'https://www.amazon.fr/'

# %%
import time
time.sleep(3)
btn = driver.find_element(By.ID, "sp-cc-accept")
btn.click()

# %%
import time
time.sleep(2)
search = driver.find_element(By.ID, "twotabsearchtextbox")
search.click()

# %%
time.sleep(3)


search.send_keys("Intelligence artificielle")
searchValidate = driver.find_element(By.ID, "nav-search-submit-button")
time.sleep(3)
searchValidate.click()

# %%
# sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 AdHolder sg-col s-widget-spacing-small sg-col-4-of-20
time.sleep(3)

# articles = driver.find_elements(By.CLASS_NAME,
#                         'sg-col-4-of-12.s-result-item.s-asin.sg-col-4-of-16.AdHolder.sg-col.s-widget-spacing-small.sg-col-4-of-20')
# # articles.append(driver.find_elements(By.CLASS_NAME,
#                         'sg-col-4-of-12.s-result-item.s-asin sg-col-4-of-16 sg-col.s-widget-spacing-small.sg-col-4-of-20'))
articles = driver.find_elements(By.CLASS_NAME,
                        'sg-col-4-of-12.s-result-item.s-asin.sg-col-4-of-16.sg-col.s-widget-spacing-small.sg-col-4-of-20')
# s-widget-container s-spacing-small s-widget-container-height-small celwidget slot=MAIN template=SEARCH_RESULTS widgetId=search-results_38
# s-card-container s-overflow-hidden aok-relative puis-expand-height puis-include-content-margin puis s-latency-cf-section s-card-border
# sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 sg-col s-widget-spacing-small sg-col-4-of-20

# %%
def get_articles_infos(articles):
    nb_art = len(articles)
    
    for n in range(nb_art):
#         print(n)
    #     a-size-base-plus a-color-base a-text-normal
        try:
            name = articles[n].find_element(By.CLASS_NAME,'a-link-normal.s-underline-text.s-underline-link-text.s-link-style.a-text-normal')
            print(name.text)
        except:
            name = articles[n].find_element(By.CLASS_NAME,'a-size-base-plus.a-color-base.a-text-normal')
            print(name.text)
        try:

            note = articles[n].find_element(By.CLASS_NAME, 'a-section.a-spacing-none.a-spacing-top-micro').find_elements(By.TAG_NAME, 'span')[0].get_attribute('aria-label')
#             note.find_elements(By.CLASS_NAME,'a-icon-alt')
            print('NOTE '+note)
        except:
            note = 'NULLOS'
            print(note)
        try:
            nb_avis = articles[n].find_element(By.CLASS_NAME,'a-row.a-size-small')
            nb_avis.find_elements(By.CLASS_NAME,'a-size-base.s-underline-text')
            print('NB : '+nb_avis.text)
        except:
            nb_avis = 'NULLOS'
            print(nb_avis)    
        try:
            prix=articles[n].find_element(By.CLASS_NAME,'a-price-whole')
            prix_symbole = articles[n].find_element(By.CLASS_NAME,'a-price-symbol')
            print('PRIX : '+prix.text+' '+prix_symbole.text)
        except:
            prix = 'NULLOS'
            print(prix)   
        try:
            link=articles[n].find_element(By.CLASS_NAME,'a-link-normal.s-no-outline').get_attribute('href')
            print(link)
        except:
            link = 'NULLOS'
            print(link)

# %%
articles[2].find_element(By.CLASS_NAME,'a-icon.a-icon-star-small.a-star-small-5.aok-align-bottom').find_element(By.TAG_NAME,'span').text
# Out:
# ''

# %%
# a-icon a-icon-star-small a-star-small-5 aok-align-bottom']
# Out:
#   Input In [110]
#     a-icon a-icon-star-small a-star-small-5 aok-align-bottom]
#            ^
# SyntaxError: invalid syntax

# %%
print(articles[2].find_element(By.CLASS_NAME, 'a-section.a-spacing-none.a-spacing-top-micro').find_elements(By.TAG_NAME, 'span')[0].get_attribute('aria-label'))
# Out:
# None

# %%
# page 1
# https://www.amazon.fr/s?k=Intelligence+artificielle&__mk_fr_FR=%C3%85M%C3%85%C5%BD%C3%95%C3%91&crid=1WN6WMRB04U96&sprefix=intelligence+artificielle%2Caps%2C367&ref=nb_sb_noss_1
# page 2
# https://www.amazon.fr/s?k=Intelligence+artificielle&page=2&__mk_fr_FR=%C3%85M%C3%85%C5%BD%C3%95%C3%91&crid=1WN6WMRB04U96&qid=1666860951&sprefix=intelligence+artificielle%2Caps%2C367&ref=sr_pg_2
# page 3
# https://www.amazon.fr/s?k=Intelligence+artificielle&page=3&__mk_fr_FR=%C3%85M%C3%85%C5%BD%C3%95%C3%91&crid=1WN6WMRB04U96&qid=1666866068&sprefix=intelligence+artificielle%2Caps%2C367&ref=sr_pg_3

# %%
get_articles_infos(articleSmall)
# Out:
# Intelligence artificielle 4e édition
# NOTE 4,7 sur 5 étoiles
# NB : 5
# PRIX : 79,00 €
# https://www.amazon.fr/Intelligence-artificielle-%C3%A9dition-Peter-Norvig/dp/2326002210/ref=sr_1_1?__mk_fr_FR=%C3%85M%C3%85%C5%BD%C3%95%C3%91&crid=1WN6WMRB04U96&keywords=Intelligence+artificielle&qid=1666866259&qu=eyJxc2MiOiI1LjEzIiwicXNhIjoiNC45MSIsInFzcCI6IjQuNzUifQ%3D%3D&sprefix=intelligence+artificielle%2Caps%2C367&sr=8-1
# Intelligence Artificielle: Notre meilleure amie?
# NULLOS
# NULLOS
# NULLOS
# https://www.amazon.fr/gp/video/ssoredirect/?ru=https%3A%2F%2Fapp.primevideo.com%2Fdetail%3Fgti%3Damzn1.dv.gti.80b88665-668d-e022-9d07-5086513c3c6f%26ref_%3Ddvm_src_ret_fr_xx_s&page-type-id=B086BRSN5L&ref=sr_1_2&keywords=Intelligence+artificielle&crid=1WN6WMRB04U96&sprefix=intelligence+artificielle%2Caps%2C367&qid=1666866259&__mk_fr_FR=%C3%85M%C3%85%C5%BD%C3%95%C3%91&sr=8-2
# L'Intelligence artificielle Pour les Nuls, NE
# NOTE 4,2 sur 5 étoiles
# NB : 39
# PRIX : 24,95 €
# ...

# %%
def the_chain(nb_pages):
    
    data = []
    start_urls = [f'https://www.amazon.fr/s?k=Intelligence+artificielle&page={n}' for n in range(1,nb_pages)]
    i = 0
    for n in range(0, nb_pages-1) :
        
        print(start_urls[n])
        lien = start_urls[n]
        time.sleep(1)
        driver.get(lien)
        
        articles = driver.find_elements(By.CLASS_NAME,
                        'sg-col-4-of-12.s-result-item.s-asin.sg-col-4-of-16.sg-col.s-widget-spacing-small.sg-col-4-of-20')
        nb_art = len(articles)
        
        for n in range(nb_art):
            
            tab = {}
            i = i+1
    #         print(n)
        #     a-size-base-plus a-color-base a-text-normal
            try:
                name = articles[n].find_element(By.CLASS_NAME,'a-link-normal.s-underline-text.s-underline-link-text.s-link-style.a-text-normal')
                print(name.text)
                tab['nom'] = str(name.text)
            except:
                name = articles[n].find_element(By.CLASS_NAME,'a-size-base-plus.a-color-base.a-text-normal')
                print(name.text)
                tab['nom']  = None
            try:

                note = articles[n].find_element(By.CLASS_NAME, 'a-row.a-size-small').find_elements(By.TAG_NAME, 'span')[0].get_attribute('aria-label')
    #             note.find_elements(By.CLASS_NAME,'a-icon-alt')
                print('NOTE '+note)
                tab['note'] = str(note)
            except:
                note = 'NULLOS'
                print(note)
                tab['note'] = None
            try:
                nb_avis = articles[n].find_element(By.CLASS_NAME,'a-row.a-size-small')
                nb_avis.find_elements(By.CLASS_NAME,'a-size-base.s-underline-text')
                print('NB : '+nb_avis.text)
                tab['nb_avis'] = str(nb_avis.text)
            except:
                nb_avis = 'NULLOS'
                print(nb_avis)
                tab['nb_avis'] = None
            try:
                prix=articles[n].find_element(By.CLASS_NAME,'a-price-whole')
                prix_symbole = articles[n].find_element(By.CLASS_NAME,'a-price-symbol')
                print('PRIX : '+prix.text+' '+prix_symbole.text)
                tab['prix'] = str(prix.text+' '+prix_symbole.text)
            except:
                prix = 'NULLOS'
                print(prix) 
                tab['prix'] = None
            try:
                link=articles[n].find_element(By.CLASS_NAME,'a-link-normal.s-no-outline').get_attribute('href')
                print(link)
                tab['link'] = str(link)
            except:
                link = 'NULLOS'
                print(link)
                tab['link'] = None
            data.append(tab)     
    print('TOTAL')            
    print(i)
    return data

# %%
print(articles[2].find_element(By.CLASS_NAME, 'a-row.a-size-small').find_elements(By.TAG_NAME, 'span')[0].get_attribute('aria-label'))
# Out:
# 5,0 sur 5 étoiles

# %%
data = the_chain(5)
# Out:
# https://www.amazon.fr/s?k=Intelligence+artificielle&page=1
# Intelligence Artificielle, Serons-Nous Remplacés?: Un Nouvel Avenir De Richesse Choquante (Intelligence artificielle, robotique, big data, robots et cyborgs t. 2)
# NULLOS
# NULLOS
# NULLOS
# https://www.amazon.fr/sspa/click?ie=UTF8&spc=MTo4Mjg4MzQ3NDQ1MDg5MDc6MTY2Njg3NjIwNTpzcF9hdGY6MjAwNTgwNDA2NTExOTg6OjA6Og&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&url=%2FIntelligence-Artificielle-Serons-Nous-Remplac%25C3%25A9s-artificielle-ebook%2Fdp%2FB09SVHTHMS%2Fref%3Dsr_1_1_sspa%3Fkeywords%3DIntelligence%2Bartificielle%26qid%3D1666876205%26qu%3DeyJxc2MiOiI1LjEzIiwicXNhIjoiNC45MSIsInFzcCI6IjQuNzUifQ%253D%253D%26sr%3D8-1-spons%26psc%3D1
# Intelligence Artificielle, La Révolution: Présent et futur (Intelligence artificielle, robotique, big data, robots et cyborgs t. 1)
# NOTE 5,0 sur 5 étoiles
# NB : 11
# NULLOS
# ...

# %%
import json
print(data)
with open('amazon.json', 'w') as file:
    json.dump(data, file, indent=2)
# Out:
# [{'nom': 'Intelligence Artificielle, Serons-Nous Remplacés?: Un Nouvel Avenir De Richesse Choquante (Intelligence artificielle, robotique, big data, robots et cyborgs t. 2)', 'note': None, 'nb_avis': None, 'prix': None, 'link': 'https://www.amazon.fr/sspa/click?ie=UTF8&spc=MTo4Mjg4MzQ3NDQ1MDg5MDc6MTY2Njg3NjIwNTpzcF9hdGY6MjAwNTgwNDA2NTExOTg6OjA6Og&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&url=%2FIntelligence-Artificielle-Serons-Nous-Remplac%25C3%25A9s-artificielle-ebook%2Fdp%2FB09SVHTHMS%2Fref%3Dsr_1_1_sspa%3Fkeywords%3DIntelligence%2Bartificielle%26qid%3D1666876205%26qu%3DeyJxc2MiOiI1LjEzIiwicXNhIjoiNC45MSIsInFzcCI6IjQuNzUifQ%253D%253D%26sr%3D8-1-spons%26psc%3D1'}, {'nom': 'Intelligence Artificielle, La Révolution: Présent et futur (Intelligence artificielle, robotique, big data, robots et cyborgs t. 1)', 'note': '5,0 sur 5\xa0étoiles', 'nb_avis': '11', 'prix': None, 'link': 'https://www.amazon.fr/sspa/click?ie=UTF8&spc=MTo4Mjg4MzQ3NDQ1MDg5MDc6MTY2Njg3NjIwNTpzcF9hdGY6MjAwNTgwMTk2NDAzOTg6OjA6Og&
# ...
